# %%
import requests
url="https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%B8%94%EB%A1%9C%EA%B7%B8"
response = requests.get(url)
html_text = response.text

# %%
pattern = r"<a.*href=['\"]([^'\"]+)['\"][^>]*>"
p = re.compile(pattern, re.I) # re.I == re.IGNORECASE
itr = p.finditer(html_text)

# %%
for m in itr:
    print(m.group())
# Out:
# <a href="#lnb"><span>메뉴 영역으로 바로가기</span></a> <a href="#content"><span>본문 영역으로 바로가기</span></a> </div><div id="wrap" ><div id="header_wrap" role="heading" class="lnb_intent"> <div class="api_floating_header">  <div class="gnb_wrap"> <div class="header_group"> <div class="search_area"> <h1 class="logo"><a href="https://www.naver.com" onclick="return goOtherCR(this, 'a=sta.naver&amp;r=&amp;i=&amp;u='+urlencode(this.href));" class="link"><i class="spnew2 ico_logo">NAVER</i></a></h1> <form id="nx_search_form" name="search" action="?" method="get" role="search" onsubmit="return nx_form_submit(this)"> <fieldset class="greenwindow"> <legend>검색</legend> <input type="hidden" name="sm" value="tab_hty.top"> <input type="hidden" name="where" value="nexearch"> <input type="hidden" name="ssc" value="tab.nx.all"> <div class="greenbox"> <input type="text" id="nx_query" name="query" class="box_window" maxlength=255 accesskey="s" value="블로그" autocomplete="off" placeholder="검색어를 입력해 주세요." data-atcmp-element> </div> <input type="hidden" name="oquery" value="블로그"> <input type="hidden" name="tqi" value="i0nQwlqVN8Vssd5btI0ssssst40-178756"> <input type="hidden" value="" name="acq" disabled> <input type="hidden" value="" name="acr" disabled> <input type="hidden" value="" name="qdt" disabled> <input type="hidden" value="" name="acir" disabled> <input type="hidden" value="" name="os" disabled> <input type="hidden" value="" name="bid" disabled> <input type="hidden" value="" name="pkid" disabled> <input type="hidden" value="" name="eid" disabled> <input type="hidden" value="" name="mra" disabled>  <div class="setkr_area"> <a id="ke_kbd_btn" role="button" href="#" class="bt_setkr" aria-pressed="false" onclick="return tCR('a=sch.ime');"> <i class="spnew2 ico_keyboard">한글 입력기</i> <div class="guide_text">입력도구</div> </a> <div id="_nx_kbd" style="display:none;"></div> </div> <!--[AU]초기화 코드는 마크업 코드 바로 뒤에 위치--> <script> (function() { var startApplication = function() { var $ = jQuery; var jsUrl = "https://ssl.pstatic.net/sstatic/fe/sfe/ime/app-1.1.0.js"; var cssUrl = "https://ssl.pstatic.net/sstatic/search/pc/css/api_keyboard_231116.css"; var ime; $("#ke_kbd_btn").on("click", function() { require([jsUrl], function(IMEKeyboard) { if (ime) { ime.toggle(); return; } ime = new IMEKeyboard({ "cssUrl": cssUrl, "selector": { "TOGGLE_BTN": "#ke_kbd_btn", "CONTENTS_AREA": "#_nx_kbd", "INPUT": "#nx_query" }, "onSearchBtnClick": function() { $("#nx_search_form").submit(); } }).toggle(); }, function(e) { alert("네트워크 상태가 안 좋아 한영 입력기를 불러오지 못했습니다.\n잠시 후 다시 시도해 주세요."); }); }); }; naver.common.load_js(null, startApplication, true, 150); })(); </script> <div class="autocomplete"> <a role="button" href="#" class="bt_atcp _btn_arw" id="nautocomplete" aria-pressed="false" data-atcmp-element><i class="spnew2 ico_arrow">자동완성 레이어</i><div class="guide_text">검색 레이어</div></a> <div id="nx_autoframe_top"></div> </div> <button type="submit" class="bt_search"> <i class="spnew2 ico_search">검색</i> <div class="guide_text">검색</div> </button> </fieldset> </form> </div>  </div> <div id="gnb"> <script> var gnb_option = { gnb_service : "search", gnb_template : "gnb_utf8", gnb_logout : encodeURIComponent(location.href), gnb_login : encodeURIComponent(location.href), gnb_brightness : 1 , gnb_item_hide_option : 0 } ; var gnb_url = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8.nhn" ; nx_js_defer_load(gnb_url + "?" + headerfooter_time_year_s + headerfooter_time_month_s + headerfooter_time_day_s + headerfooter_time_hour_s, function() { getGNB() ; /* GNB Layer 찌꺼기 제거 대응 */ $Fn(function(we) { if (typeof gnbAllLayerClose == "function") { var bShowLayer = gnbUserLayer.show || gnbNaverMeLayer.show || gnbMoreLayer.show; var bClickGNBArea = $Element($$.getSingle("ul.gnb_lst")).isEqual(we.element) || $Element($$.getSingle("ul.gnb_lst")).isParentOf(we.element); if (bShowLayer && !bClickGNBArea) { gnbAllLayerClose(); } } }, this).attach(document, "click"); }, 0) ; </script> </div> </div><script type="text/java ...
# <a href="javascript:void(0);" role="button" class="api_ad_link" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">
# <a href="//saedu.naver.com/adbiz/searchad/clickChoice.naver" class="sub_link" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));"
#           >
# <a href="https://help.naver.com/service/5626/contents/1419" class="link">
# <a href="https://adcr.naver.com/adcr?x=Nee7PLxQRuWPbUz3v3x9q////w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=Nee7PLxQRuWPbUz3v3x9q////w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=Nee7PLxQRuWPbUz3v3x9q////w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=Nee7PLxQRuWPbUz3v3x9q////w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39; + urlencode(&#39;https://biz.revu.net/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=Nee7PLxQRuWPbUz3v3x9q////w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39; + urlencode(&#39;https://biz.revu.net/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=nUi/sirn9fLKXkoywEsPkv///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=oYE/oHla/SSeoMoJHvXh/P///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=IPIVQfOeqvWNFpswQzAGgP///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=layZlybUVkfHBcYkGwxLTv///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=KX6dZAHT2EO5xVhrBYe6RP///w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39;+urlencode(&#39;http://stormdayz.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=KX6dZAHT2EO5xVhrBYe6RP///w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39;+urlencode(&#39;http://stormdayz.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=KX6dZAHT2EO5xVhrBYe6RP///w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39;+urlencode(&#39;http://stormdayz.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=KX6dZAHT2EO5xVhrBYe6RP///w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39; + urlencode(&#39;http://stormdayz.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=KX6dZAHT2EO5xVhrBYe6RP///w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39; + urlencode(&#39;http://stormdayz.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=CbdcdJ4a3ltBsekxyy+2/f///w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://m.pay.naver.com/mobile/about" target="_blank" class="ly_ad _tooltip"
#                          style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                          onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                          onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                          onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.checkout&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=CbdcdJ4a3ltBsekxyy+2/f///w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=CbdcdJ4a3ltBsekxyy+2/f///w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=CbdcdJ4a3ltBsekxyy+2/f///w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39; + urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=CbdcdJ4a3ltBsekxyy+2/f///w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39; + urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=ldKBue4oA/pBPLgE6mtnT////w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=e4LDJjH20ej+D+ev8G/3m////w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=+qCI6P0CkHS/j/LKoSW5IP///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=VY5z7+iAX8EBWgCD/MSgc////w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=7Q5ZlxtKAaUkXwS7eIDuLf///w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=4&amp;i=nad-a001-01-000000312625490&amp;d=&#39;+urlencode(&#39;https://admaru.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=7Q5ZlxtKAaUkXwS7eIDuLf///w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000312625490&amp;d=&#39;+urlencode(&#39;https://admaru.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=7Q5ZlxtKAaUkXwS7eIDuLf///w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000312625490&amp;d=&#39;+urlencode(&#39;https://admaru.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=7Q5ZlxtKAaUkXwS7eIDuLf///w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000312625490&amp;d=&#39; + urlencode(&#39;https://admaru.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=7Q5ZlxtKAaUkXwS7eIDuLf///w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=4&amp;i=nad-a001-01-000000312625490&amp;d=&#39; + urlencode(&#39;https://admaru.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=uUMQZ7aQrzmMJZB/8rSz2////w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=4&amp;i=nad-a001-01-000000312625490&amp;d=&#39;+urlencode(&#39;https://admaru.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=H55cQtk+MOjcacRpy/rcJP///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=4&amp;i=nad-a001-01-000000312625490&amp;d=&#39;+urlencode(&#39;https://admaru.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=4wkwVJdLCRTzKPDvjUjAyf///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=4&amp;i=nad-a001-01-000000312625490&amp;d=&#39;+urlencode(&#39;https://admaru.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=mJeq1qa7/WK4/xsM0uNBEf///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=4&amp;i=nad-a001-01-000000312625490&amp;d=&#39;+urlencode(&#39;https://admaru.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=b/X2bqopdNyB2Elwv4QaR////w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" class="ly_ad _tooltip"
#                          style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                          onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                          onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                          onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=b/X2bqopdNyB2Elwv4QaR////w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=b/X2bqopdNyB2Elwv4QaR////w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=b/X2bqopdNyB2Elwv4QaR////w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39; + urlencode(&#39;http://www.reviewplace.co.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=b/X2bqopdNyB2Elwv4QaR////w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39; + urlencode(&#39;http://www.reviewplace.co.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=rQjStt79pFwG7W4LfrcvM////w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=v6FIbbAfDmD/Kh2TjXvXlv///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a class="link" href="https://adcr.naver.com/adcr?x=bElI0AXGv4TdJv+mp5z9zv///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=QidSfdReB8GVQly7xuh+c////w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39;+urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=QidSfdReB8GVQly7xuh+c////w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39;+urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=QidSfdReB8GVQly7xuh+c////w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39;+urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=QidSfdReB8GVQly7xuh+c////w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39; + urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=QidSfdReB8GVQly7xuh+c////w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39; + urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=/XDt7vmEaYaAE+N0X1cj8f///w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=7&amp;i=nad-a001-01-000000296906665&amp;d=&#39;+urlencode(&#39;http://www.gmarket.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" class="ly_ad _tooltip"
#                          style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                          onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                          onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                          onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=7&amp;i=nad-a001-01-000000296906665&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=/XDt7vmEaYaAE+N0X1cj8f///w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000296906665&amp;d=&#39;+urlencode(&#39;http://www.gmarket.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=/XDt7vmEaYaAE+N0X1cj8f///w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000296906665&amp;d=&#39;+urlencode(&#39;http://www.gmarket.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=/XDt7vmEaYaAE+N0X1cj8f///w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000296906665&amp;d=&#39; + urlencode(&#39;http://www.gmarket.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a href="https://adcr.naver.com/adcr?x=/XDt7vmEaYaAE+N0X1cj8f///w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=7&amp;i=nad-a001-01-000000296906665&amp;d=&#39; + urlencode(&#39;http://www.gmarket.co.kr&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
# <a target="_blank" id="preview_headline" href="" onclick="" class="txt">
# <a target="_blank" id="preview_find_map" href="" onclick="" class="sp_ad_map ico_find_road">
# <a target="_blank" id="preview_display_url" href="" onclick="" class="txt">
# <a href="javascript:;" class="sp_ad_mall btn_clse" id="map_btn_clse">
# <a href="#" role="button" class="btn_save _keep_trigger" data-url="https://section.blog.naver.com/" onclick='tCR("a=sit_5po*e.kep&amp;r=&amp;i=&amp;u=javascript")'><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer"><a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=sit_5po*e.keepon" data-cr-off="a=sit_5po*e.keepoff">
# <a target="_blank" href="https://keep.naver.com/" class="spnew_af item item_quick" onclick='goOtherCR(this,"a=sit_5po*e.kep&amp;r=1&amp;i=a00000fa_401bcd22cf5791d5e084fc7e%5Efab&amp;u="+urlencode(this.href))'>Keep 바로가기</a></div></div><div class="source_box"><a target="_blank" href="https://section.blog.naver.com/" class="thumb" onclick='goOtherCR(this,"a=sit_5po*e.link&amp;r=1&amp;i=a00000fa_401bcd22cf5791d5e084fc7e%5Efab&amp;u="+urlencode(this.href))'><img data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fssl.pstatic.net%2Ft.static.blog%2Fpcfe%2Fstatic%2Fpc_favicon.ico%3F2&amp;type=f30_30_png_expire24" width="16" height="16" alt src="..."></a><a target="_blank" href="https://section.blog.naver.com/" class="link_source" onclick='goOtherCR(this,"a=sit_5po*e.link&amp;r=1&amp;i=a00000fa_401bcd22cf5791d5e084fc7e%5Efab&amp;u="+urlencode(this.href))'><span class="name">네이버 블로그</span><span class="txt">section.blog.naver.com</span></a></div></div></div><div class="total_group"><div class="total_tit"><a target="_blank" href="https://section.blog.naver.com/" class="link_tit" onclick='goOtherCR(this,"a=sit_5po*e.link&amp;r=1&amp;i=a00000fa_401bcd22cf5791d5e084fc7e%5Efab&amp;u="+urlencode(this.href))'>네이버 <mark>블로그</mark></a></div><div class="group_item"><ul class="list_item"><li class="item"><a target="_blank" href="https://section.blog.naver.com/OfficialBlog.nhn?currentPage=1" onclick='goOtherCR(this,"a=sit_5po*e.sublink&amp;r=1&amp;i=a00000fa_401bcd22cf5791d5e084fc7e%5Efab&amp;u="+urlencode(this.href))'>공식<mark>블로그</mark></a></li><li class="item"><a target="_blank" href="https://section.blog.naver.com/ThisMonthDirectory.nhn" onclick='goOtherCR(this,"a=sit_5po*e.sublink&amp;r=1&amp;i=a00000fa_401bcd22cf5791d5e084fc7e%5Efab&amp;u="+urlencode(this.href))'>이달의 <mark>블로그</mark></a></li><li class="item"><a target="_blank" href="http://section.blog.naver.com/ThemePost.nhn" onclick='goOtherCR(this,"a=sit_5po*e.sublink&amp;r=1&amp;i=a00000fa_401bcd22cf5791d5e084fc7e%5Efab&amp;u="+urlencode(this.href))'>오늘의 TOP</a></li><li class="item"><a target="_blank" href="http://section.blog.naver.com/HotTopicChallenge.nhn" onclick='goOtherCR(this,"a=sit_5po*e.sublink&amp;r=1&amp;i=a00000fa_401bcd22cf5791d5e084fc7e%5Efab&amp;u="+urlencode(this.href))'><mark>블로그</mark> 핫토픽</a></li></ul></div><div class="total_dsc_wrap"><a target="_blank" href="https://section.blog.naver.com/" class="api_txt_lines total_dsc type_3lines" onclick='goOtherCR(this,"a=sit_5po*e.link&amp;r=1&amp;i=a00000fa_401bcd22cf5791d5e084fc7e%5Efab&amp;u="+urlencode(this.href))'>당신의 모든 기록을 담는 공간</a></div></div></div></li></ul></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/commonPortal/pc_240116.js",t=function(){var t=window.require.config({context:"_fe_web_commonportal",paths:{Controller:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),t(["Controller"],function(e){var t=jQuery("._fe_root_sit_5pod"),n=new e(t);n.on({"tab-scroll":function(e){e.isTrusted},"content-scroll":function(e){if(e.isTrusted){var t=e.$wrapper.find("._freescroll_flicking").attr("data-log");t&&tCR(t)}},"click-infolayer-trigger-button":function(e){e.isOn}})})},n=naver.common.gv.REQUIRE_JS;naver.common.load_js(window.require?null:n,t,!0,150)})()</script><script>(function(){var e,n="_sp_ntotal",s="type_margin",t=Array.prototype.slice.call(document.querySelectorAll("section."+n));function o(e,t){return e.matches?e.matches(t):!!e.msMatchesSelector&&e.msMatchesSelector(t)}function i(e){var t=e,s=t.tagName.toLowerCase();do t=t.previousElementSibling,s=t?t.tagName.toLowerCase():"";while(t!==null&&(s==="script"||s==="link"))return t!==null&&s==="section"&&o(t,"."+n)}for(e=0;e<t.length;++e)i(t[e])&&t[e].classList.add(s)})()</script><div class="_scrollLog" data-slog-id="sit_5po*e" style="visibility:hidden;height:0px;margin:0 28px"></div><link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_intent_faq_240613.css"><section class="sc_new sp_int ...
# <a href="https://blog.naver.com/woodrooster/223057701369" class="profile_link" onclick='return goOtherCR(this,"a=exB_soT*q.paaprofile&amp;r=1&amp;i=90000003_0000000000000033EF4669F9&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">
# <a href="#" role="button" class="btn_save _keep_trigger" data-cr-on="a=exB_soT*q.keep&r=1&i=90000003_0000000000000033EF4669F9&u=javascript" data-cr-off="a=exB_soT*q.keep&r=1&i=90000003_0000000000000033EF4669F9&u=javascript" data-url="https://blog.naver.com/woodrooster/223057701369" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer" style="display:none;"><a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=exB_soT*q.keepon&r=1&i=90000003_0000000000000033EF4669F9&u=javascript" data-cr-off="a=exB_soT*q.keepoff&r=1&i=90000003_0000000000000033EF4669F9&u=javascript">
# <a href="https://keep.naver.com/" class="spnew_af item item_quick" onclick='return goOtherCR(this,"a=exB_soT*q.keephome&amp;r=1&amp;i=90000003_0000000000000033EF4669F9&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">Keep 바로가기</a></div></div></div><a href="https://blog.naver.com/woodrooster/223057701369" class="answer" onclick='return goOtherCR(this,"a=exB_soT*q.paalink&amp;r=1&amp;i=90000003_0000000000000033EF4669F9&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">블로그를 새로 시작 하거나 바꾸고 싶은 분들은 네이버의 ID를 새로 개설하시면 됩니다. 네이버의 ID는 3개까지 계정 생성이 가능하며, 이는 곧 블로그도 3개까지는 운영할 수 있다는 의미입니다. 네이버에 신규 가입하고 블로그를 운영하고 싶으시다면 블로그 ID만 새로 만들고 블로그를 시작하시면 됩니다.</a><div class="subinfo_box"><div class="info">Ai 스니펫 기술로 생성된 Q&A입니다.</div><div class="more_area"><a href="https://blog.naver.com/woodrooster/223057701369" class="spib_af link_more" onclick='return goOtherCR(this,"a=exB_soT*q.linkmore&amp;r=1&amp;i=90000003_0000000000000033EF4669F9&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">더보기</a></div></div></div></li><li class="faq_item"><a href="https://springlevelup.com/%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%B8%94%EB%A1%9C%EA%B7%B8-%EC%9E%91%EC%84%B1-%EA%B0%80%EC%9D%B4%EB%93%9C/" class="question_wrap _au_question_wrap" role="button" aria-expanded="false" target="_blank" data-query="&faq_opened=">
# <a href="https://springlevelup.com/%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%B8%94%EB%A1%9C%EA%B7%B8-%EC%9E%91%EC%84%B1-%EA%B0%80%EC%9D%B4%EB%93%9C/" class="profile_link" onclick='return goOtherCR(this,"a=exB_soT*q.paaprofile&amp;r=2&amp;i=a00000fa_67a86e28ae284a30efe0c87a&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">
# <a href="#" role="button" class="btn_save _keep_trigger" data-cr-on="a=exB_soT*q.keep&r=2&i=a00000fa_67a86e28ae284a30efe0c87a&u=javascript" data-cr-off="a=exB_soT*q.keep&r=2&i=a00000fa_67a86e28ae284a30efe0c87a&u=javascript" data-url="https://springlevelup.com/%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%B8%94%EB%A1%9C%EA%B7%B8-%EC%9E%91%EC%84%B1-%EA%B0%80%EC%9D%B4%EB%93%9C/" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer" style="display:none;"><a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=exB_soT*q.keepon&r=2&i=a00000fa_67a86e28ae284a30efe0c87a&u=javascript" data-cr-off="a=exB_soT*q.keepoff&r=2&i=a00000fa_67a86e28ae284a30efe0c87a&u=javascript">
# <a href="https://keep.naver.com/" class="spnew_af item item_quick" onclick='return goOtherCR(this,"a=exB_soT*q.keephome&amp;r=2&amp;i=a00000fa_67a86e28ae284a30efe0c87a&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">Keep 바로가기</a></div></div></div><a href="https://springlevelup.com/%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%B8%94%EB%A1%9C%EA%B7%B8-%EC%9E%91%EC%84%B1-%EA%B0%80%EC%9D%B4%EB%93%9C/" class="answer" onclick='return goOtherCR(this,"a=exB_soT*q.paalink&amp;r=2&amp;i=a00000fa_67a86e28ae284a30efe0c87a&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">PC버전을 기준으로, 네이버 화면에서 로그인하면 위 사진과 같은 화면이 뜹니다. 여기서 1이라고 표시해둔 ‘블로그’를 누르면 아래 메뉴가 펼쳐지게 되는데, 거기서 조금 더 아래부분 2라고 표시해둔 부분의 ‘내블로그’ 메뉴를 확인해보시면 되겠습니다. 해당 메뉴를 클릭하면 바로 내 블로그에 접속할 수 있습니다.</a><div class="subinfo_box"><div class="info">Ai 스니펫 기술로 생성된 Q&A입니다.</div><div class="more_area"><a href="https://springlevelup.com/%EB%84%A4%EC%9D%B4%EB%B2%84-%EB%B8%94%EB%A1%9C%EA%B7%B8-%EC%9E%91%EC%84%B1-%EA%B0%80%EC%9D%B4%EB%93%9C/" class="spib_af link_more" onclick='return goOtherCR(this,"a=exB_soT*q.linkmore&amp;r=2&amp;i=a00000fa_67a86e28ae284a30efe0c87a&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">더보기</a></div></div></div></li><li class="faq_item"><a href="https://sy16.tistory.com/28" class="question_wrap _au_question_wrap" role="button" aria-expanded="false" target="_blank" data-query="&faq_opened=">
# <a href="https://sy16.tistory.com/28" class="profile_link" onclick='return goOtherCR(this,"a=exB_soT*q.paaprofile&amp;r=3&amp;i=a00000fa_9b2f692003ea6eaf498a1bb7&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">
# <a href="#" role="button" class="btn_save _keep_trigger" data-cr-on="a=exB_soT*q.keep&r=3&i=a00000fa_9b2f692003ea6eaf498a1bb7&u=javascript" data-cr-off="a=exB_soT*q.keep&r=3&i=a00000fa_9b2f692003ea6eaf498a1bb7&u=javascript" data-url="https://sy16.tistory.com/28" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer" style="display:none;"><a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=exB_soT*q.keepon&r=3&i=a00000fa_9b2f692003ea6eaf498a1bb7&u=javascript" data-cr-off="a=exB_soT*q.keepoff&r=3&i=a00000fa_9b2f692003ea6eaf498a1bb7&u=javascript">
# <a href="https://keep.naver.com/" class="spnew_af item item_quick" onclick='return goOtherCR(this,"a=exB_soT*q.keephome&amp;r=3&amp;i=a00000fa_9b2f692003ea6eaf498a1bb7&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">Keep 바로가기</a></div></div></div><a href="https://sy16.tistory.com/28" class="answer" onclick='return goOtherCR(this,"a=exB_soT*q.paalink&amp;r=3&amp;i=a00000fa_9b2f692003ea6eaf498a1bb7&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">계획만 거창하고 계획대로 끝까지 못이루는 것이 대다수이다. 그렇기에 블로그를 쓰는 이유를 글로 남겨서 이후 이 글을 한번씩 보면서 초심을 떠올리고 블로그를 계속 쓰게하기 위함이다.</a><div class="subinfo_box"><div class="info">Ai 스니펫 기술로 생성된 Q&A입니다.</div><div class="more_area"><a href="https://sy16.tistory.com/28" class="spib_af link_more" onclick='return goOtherCR(this,"a=exB_soT*q.linkmore&amp;r=3&amp;i=a00000fa_9b2f692003ea6eaf498a1bb7&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">더보기</a></div></div></div></li><li class="faq_item"><a href="https://blog.naver.com/pakseung98/70118414119" class="question_wrap _au_question_wrap" role="button" aria-expanded="false" target="_blank" data-query="&faq_opened=">
# <a href="https://blog.naver.com/pakseung98/70118414119" class="profile_link" onclick='return goOtherCR(this,"a=exB_soT*q.paaprofile&amp;r=4&amp;i=90000003_000000000000001053621727&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">
# <a href="#" role="button" class="btn_save _keep_trigger" data-cr-on="a=exB_soT*q.keep&r=4&i=90000003_000000000000001053621727&u=javascript" data-cr-off="a=exB_soT*q.keep&r=4&i=90000003_000000000000001053621727&u=javascript" data-url="https://blog.naver.com/pakseung98/70118414119" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer" style="display:none;"><a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=exB_soT*q.keepon&r=4&i=90000003_000000000000001053621727&u=javascript" data-cr-off="a=exB_soT*q.keepoff&r=4&i=90000003_000000000000001053621727&u=javascript">
# <a href="https://keep.naver.com/" class="spnew_af item item_quick" onclick='return goOtherCR(this,"a=exB_soT*q.keephome&amp;r=4&amp;i=90000003_000000000000001053621727&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">Keep 바로가기</a></div></div></div><a href="https://blog.naver.com/pakseung98/70118414119" class="answer" onclick='return goOtherCR(this,"a=exB_soT*q.paalink&amp;r=4&amp;i=90000003_000000000000001053621727&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">네이버 블로그의 구조는 크게 7개 구조를 나눌 수 있는데요. 7부분의 명칭은 ① 스킨 ② 네이버메뉴 ③ 타이틀 ④ 메뉴형태 ⑤ 왼쪽 사이드바 ⑥ 오른쪽 사이드바 ⑦ 포스트영역 으로 지칭합니다. 다음 이미지를 보시면 도움이 되실 것입니다.</a><div class="subinfo_box"><div class="info">Ai 스니펫 기술로 생성된 Q&A입니다.</div><div class="more_area"><a href="https://blog.naver.com/pakseung98/70118414119" class="spib_af link_more" onclick='return goOtherCR(this,"a=exB_soT*q.linkmore&amp;r=4&amp;i=90000003_000000000000001053621727&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">더보기</a></div></div></div></li><li class="faq_item"><a href="https://contents.premium.naver.com/jaykee/linkjuice/contents/231205100617475mw" class="question_wrap _au_question_wrap" role="button" aria-expanded="false" target="_blank" data-query="&faq_opened=">
# <a href="https://contents.premium.naver.com/jaykee/linkjuice/contents/231205100617475mw" class="profile_link" onclick='return goOtherCR(this,"a=exB_soT*q.paaprofile&amp;r=5&amp;i=a00000fa_7af3b9bb4ed8e4ce5f2a4ab2&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">
# <a href="#" role="button" class="btn_save _keep_trigger" data-cr-on="a=exB_soT*q.keep&r=5&i=a00000fa_7af3b9bb4ed8e4ce5f2a4ab2&u=javascript" data-cr-off="a=exB_soT*q.keep&r=5&i=a00000fa_7af3b9bb4ed8e4ce5f2a4ab2&u=javascript" data-url="https://contents.premium.naver.com/jaykee/linkjuice/contents/231205100617475mw" aria-pressed="false"><i class="spnew ico_save">문서 저장하기</i></a><div class="api_ly_save _keep_save_layer" style="display:none;"><a href="#" role="button" class="spnew_af item item_save _keep_save" data-cr-on="a=exB_soT*q.keepon&r=5&i=a00000fa_7af3b9bb4ed8e4ce5f2a4ab2&u=javascript" data-cr-off="a=exB_soT*q.keepoff&r=5&i=a00000fa_7af3b9bb4ed8e4ce5f2a4ab2&u=javascript">
# <a href="https://keep.naver.com/" class="spnew_af item item_quick" onclick='return goOtherCR(this,"a=exB_soT*q.keephome&amp;r=5&amp;i=a00000fa_7af3b9bb4ed8e4ce5f2a4ab2&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">Keep 바로가기</a></div></div></div><a href="https://contents.premium.naver.com/jaykee/linkjuice/contents/231205100617475mw" class="answer" onclick='return goOtherCR(this,"a=exB_soT*q.paalink&amp;r=5&amp;i=a00000fa_7af3b9bb4ed8e4ce5f2a4ab2&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">그렇기때문에 Tier1을 한다고 하였을 때 네이버 블로그를 사용하라고 추천해주고 싶은 블로그입니다. 수익적인 부분을 떠나서 트래픽 양이 풍부하다보니, 매력적인 블로그입니다. CPA를 하시는 분들은 블로그를 잘 활용하고 외부 링크를 붙일때 조심만 한다면, 좋은 성과를 낼 수 있는 블로그 이기도 합니다.</a><div class="subinfo_box"><div class="info">Ai 스니펫 기술로 생성된 Q&A입니다.</div><div class="more_area"><a href="https://contents.premium.naver.com/jaykee/linkjuice/contents/231205100617475mw" class="spib_af link_more" onclick='return goOtherCR(this,"a=exB_soT*q.linkmore&amp;r=5&amp;i=a00000fa_7af3b9bb4ed8e4ce5f2a4ab2&amp;u="+urlencode(urlexpand(this.href)))' target="_blank">더보기</a></div></div></div></li></ul><div class="mod_more_wrap"><a href="#lb_api=https%3a%2f%2fs.search.naver.com%2fp%2fkin%2f50%2fsearch.naver%3fquery%3d%25EB%25B8%2594%25EB%25A1%259C%25EA%25B7%25B8%26sqs%3d%257B%2522intentblock%2522%253A%257B%2522v%2522%253A%25223%2522%252C%2522collections%2522%253A%257B%2522kin%2522%253A%257B%2522blocks%2522%253A%255B%255D%252C%2522qid%2522%253A%2522%25EB%25B8%2594%25EB%25A1%259C%25EA%25B7%25B8%2522%252C%2522extras%2522%253A%257B%2522faq%2522%253A%257B%2522expose%2522%253A%25221%2522%252C%2522togetherKeywords%2522%253A%255B%255D%252C%2522relatedKeywords%2522%253A%255B%255D%257D%252C%2522expert%2522%253A%257B%2522expose%2522%253A%25220%2522%252C%2522category%2522%253A%257B%2522id%2522%253A%2522%2522%257D%252C%2522collPos%2522%253A%2522default%2522%257D%252C%2522qna%2522%253A%257B%2522expose%2522%253A%25220%2522%257D%257D%252C%2522faq%2522%253A%257B%2522expose%2522%253A%25221%2522%252C%2522togetherKeywords%2522%253A%255B%255D%252C%2522relatedKeywords%2522%253A%255B%255D%257D%252C%2522expert%2522%253A%257B%2522expose%2522%253A%25220%2522%252C%2522category%2522%253A%257B%2522id%2522%253A%2522%2522%257D%252C%2522collPos%2522%253A%2522default%2522%257D%252C%2522qna%2522%253A%257B%2522expose%2522%253A%25220%2522%257D%257D%257D%252C%2522sbs_key%2522%253A%2522kin-%25EB%25B8%2594%25EB%25A1%259C%25EA%25B7%25B8-06bf14c8b8b6f675001ddea3f9c3f854%2522%257D%257D%26where%3dpc_faq_bridge" data-lb-trigger="https://s.search.naver.com/p/kin/50/search.naver?query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sqs=%7B%22intentblock%22%3A%7B%22v%22%3A%223%22%2C%22collections%22%3A%7B%22kin%22%3A%7B%22blocks%22%3A%5B%5D%2C%22qid%22%3A%22%EB%B8%94%EB%A1%9C%EA%B7%B8%22%2C%22extras%22%3A%7B%22faq%22%3A%7B%22expose%22%3A%221%22%2C%22togetherKeywords%22%3A%5B%5D%2C%22relatedKeywords%22%3A%5B%5D%7D%2C%22expert%22%3A%7B%22expose%22%3A%220%22%2C%22category%22%3A%7B%22id%22%3A%22%22%7D%2C%22collPos%22%3A%22default%22%7D%2C%22qna%22%3A%7B%22expose%22%3A%220%22%7D%7D%2C%22faq%22%3A%7B%22expose%22%3A%221%22%2C%22togetherKeywords%22%3A%5B%5D%2C%22relatedKeywords%22%3A%5B%5D%7D%2C%22expert%22%3A%7B%22expose%22%3A%220%22%2C%22category%22%3A%7B%22id%22%3A%22%22%7D%2C%22collPos%22%3A%22default%22%7D%2C%22qna%22%3A%7B%22expose%22%3A%220%22%7D%7D%7D%2C%22sbs_key%22%3A%22kin-%EB%B8%94%EB%A1%9C%EA%B7%B8-06bf14c8b8b6f675001ddea3f9c3f854%22%7D%7D&amp;where=pc_faq_bridge" class="group_more _au_api_more" onclick='return tCR("a=exB_soT.more&amp;r=0&amp;i=&amp;u=javascript")'>블로그 FAQ 더보기<i class="spnew ico_arr"></i></a></div></div></section><script>(function(){var e="https://ssl.pstatic.net/sstatic/fe/sfe/ugc/intent-faq-pc/IntentFaqPortal-1.1.0.js",t=function(){var t=window.require.config({context:"intent-faq-pc-portal",paths:{IntentFaqPortal:e.replace(/\.js$/,"")}});define("jquery",[],function(){return jQuery}),t(["IntentFaqPortal"],function(e){var t=new e({section:"._au_sp_intent_faq",tooltip:{root:"._fe_faq_tooltip"} ...
# <a target="_blank" href="https://keep.naver.com/" class="spnew_af item item_quick" onclick='goOtherCR(this,"a=web_gen*w.kep&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u="+urlencode(this.href))'>Keep 바로가기</a></div></div><div class="source_box"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8" class="thumb" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u="+urlencode(this.href))'><img data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fko.wikipedia.org%2Ffavicon.ico&amp;type=f30_30_png_expire24" width="16" height="16" alt src="..."></a><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8" class="link_source" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u="+urlencode(this.href))'><span class="name">위키백과 한국어</span><span class="txt">ko.wikipedia.org<i class="divide">›</i>블로그</span></a></div></div></div><div class="total_group"><div class="total_tit"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8" class="link_tit" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u="+urlencode(this.href))'><mark>블로그</mark> - 위키백과 한국어</a></div><div class="total_dsc_wrap"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8" class="api_txt_lines total_dsc type_3lines" onclick='goOtherCR(this,"a=web_gen*w.link&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u="+urlencode(this.href))'><mark>블로그</mark> ( 영어: <mark>blog</mark> 또는 weblog )는 정보 공유나 의견 교환을 목적으로 올리는 글을 모아 월드 와이드 웹상에 게시하는 웹사이트의 일종이다. <mark>블로그</mark>라는 말은 웹(web)과 로그(log, 기록)를 합친 낱말로, 스스로가 가진 느낌이나 품어오던 생각, 알리고 싶은 견해나 주장 같은 것을 일기처럼 차곡차곡 적어 올리는 형식을 취한다. 이를 다른 사람도 보고 읽을 수 있으며, 보통 시간 순서대로 가장 최근의 글부터 보인다. 그러나 글 쓴 시간을 수정할 수 있는 <mark>블로그</mark>의 경우에는 시간을 고쳐 글 순서를 바꿀 수 있다. 여러 사람이 쓸 수 ...</a></div></div></div><div class="snippet_rel_wrap"><ul class="list_rel"><li class="bx"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8#%EA%B0%9C%EC%9A%94" class="link_item" onclick='tCR("a=web_gen*w.relink&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u=javascript")'>개요</a></li><li class="bx"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8#%EC%97%AD%EC%82%AC" class="link_item" onclick='tCR("a=web_gen*w.relink&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u=javascript")'>역사</a></li><li class="bx"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8#%EC%A2%85%EB%A5%98" class="link_item" onclick='tCR("a=web_gen*w.relink&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u=javascript")'>종류</a></li><li class="bx"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8#%EB%8B%A4%EB%A5%B8_%EC%9C%A0%EC%82%AC_%EC%84%9C%EB%B9%84%EC%8A%A4%EC%99%80_%EB%B9%84%EA%B5%90" class="link_item" onclick='tCR("a=web_gen*w.relink&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u=javascript")'>다른 유사 서비스와 비교</a></li><li class="bx"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8#%EC%88%98%EC%9D%B5" class="link_item" onclick='tCR("a=web_gen*w.relink&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u=javascript")'>수익</a></li><li class="bx"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8#%EA%B0%99%EC%9D%B4_%EB%B3%B4%EA%B8%B0" class="link_item" onclick='tCR("a=web_gen*w.relink&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u=javascript")'>같이 보기</a></li><li class="bx"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8%94%EB%A1%9C%EA%B7%B8#%EA%B0%81%EC%A3%BC" class="link_item" onclick='tCR("a=web_gen*w.relink&amp;r=1&amp;i=a00000fa_9a17fecc698b93495f19eb63%5Efac&amp;u=javascript")'>각주</a></li><li class="bx"><a target="_blank" href="https://ko.wikipedia.org/wiki/%EB%B8 ...
# ...
# <a nocr="1" href="https://cafe.naver.com/directwedding" class="DHukbqvLPOXU2MlU1a0g EzNkJXXEnI4Z7V6swnFh" target="_blank">
# <a nocr="1" href="https://cafe.naver.com/directwedding" class="DHukbqvLPOXU2MlU1a0g" target="_blank">
# <a nocr="1" href="http://cafe.naver.com/directwedding/7085067?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImRpcmVjdHdlZGRpbmciLCJhcnRpY2xlSWQiOjcwODUwNjcsImlzc3VlZEF0IjoxNzMyNTAxNDQyOTUwfQ.voaOZBc7Dk0ylZLbO32Az2nWJLs5LteeGFhfRunfv9U" class="DHukbqvLPOXU2MlU1a0g GxUmIoU8s2hAaEmbtMpE" target="_blank"><div class="aP5cLUcLjx_Fx9gMuOvQ idylRzgFhiSXk5gTlWnj"><div class="QRmos_1QilWZ3PjNpQwU idylRzgFhiSXk5gTlWnj"><div class="sDuQ8VNY0Y5EasY7sJMT PM5uqnnof_rRq83viDFg idylRzgFhiSXk5gTlWnj"><span class="pyY0f7u443HUSUqESW4C beQwGlWUeUbyxn4Un5OE">[포인트 소통게시판]</span></div><span class="IcXP7mRiD50miFBaMmKX beQwGlWUeUbyxn4Un5OE"><mark>블로그</mark> 정보공유 승인거절 사유</span></div><div class="Q3XDmXBUSnsRZgPpEwIK idylRzgFhiSXk5gTlWnj"><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">2주 전</span><div class="pp_0VysqQ_HycljoTxin pwHV7Ne8t_6a_C3KLnig"></div><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">댓글 6</span></div></div></a><div class="pp_0VysqQ_HycljoTxin"></div><a nocr="1" href="http://cafe.naver.com/directwedding/7100804?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImRpcmVjdHdlZGRpbmciLCJhcnRpY2xlSWQiOjcxMDA4MDQsImlzc3VlZEF0IjoxNzMyNTAxNDQyOTUwfQ.86RmEviYlP_fDyST_41DxjMGSZBfQZVGBIywuxEKffs" class="DHukbqvLPOXU2MlU1a0g GxUmIoU8s2hAaEmbtMpE" target="_blank"><div class="aP5cLUcLjx_Fx9gMuOvQ idylRzgFhiSXk5gTlWnj"><div class="QRmos_1QilWZ3PjNpQwU idylRzgFhiSXk5gTlWnj"><div class="sDuQ8VNY0Y5EasY7sJMT PM5uqnnof_rRq83viDFg idylRzgFhiSXk5gTlWnj"><span class="pyY0f7u443HUSUqESW4C beQwGlWUeUbyxn4Un5OE">[포인트 소통게시판]</span></div><span class="IcXP7mRiD50miFBaMmKX beQwGlWUeUbyxn4Un5OE"><mark>블로그</mark> 안하는 신부님들..포인트얼마나 모으셨나요..</span></div><div class="Q3XDmXBUSnsRZgPpEwIK idylRzgFhiSXk5gTlWnj"><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">1주 전</span><div class="pp_0VysqQ_HycljoTxin pwHV7Ne8t_6a_C3KLnig"></div><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">댓글 33</span></div></div></a></div></div></div><div class="jy_7bFnZxjKxnsZTqob2 idylRzgFhiSXk5gTlWnj" data-template-id="ugcCafeItem"><div class="KdXS4gty0h2yFULwxIbA idylRzgFhiSXk5gTlWnj"><a nocr="1" href="https://cafe.naver.com/makegoodstudy" class="DHukbqvLPOXU2MlU1a0g" target="_blank">
# <a nocr="1" href="https://cafe.naver.com/makegoodstudy" class="DHukbqvLPOXU2MlU1a0g EzNkJXXEnI4Z7V6swnFh" target="_blank">
# <a nocr="1" href="https://cafe.naver.com/makegoodstudy" class="DHukbqvLPOXU2MlU1a0g" target="_blank">
# <a nocr="1" href="http://cafe.naver.com/makegoodstudy/663755?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Im1ha2Vnb29kc3R1ZHkiLCJhcnRpY2xlSWQiOjY2Mzc1NSwiaXNzdWVkQXQiOjE3MzI1MDE0NDI5NTB9.Z_sEcrp_rRY2NVT_M0PlPnfdtEIbYQdHe1Hec56l-GU" class="DHukbqvLPOXU2MlU1a0g GxUmIoU8s2hAaEmbtMpE" target="_blank"><div class="aP5cLUcLjx_Fx9gMuOvQ idylRzgFhiSXk5gTlWnj"><div class="QRmos_1QilWZ3PjNpQwU idylRzgFhiSXk5gTlWnj"><div class="sDuQ8VNY0Y5EasY7sJMT PM5uqnnof_rRq83viDFg idylRzgFhiSXk5gTlWnj"><span class="pyY0f7u443HUSUqESW4C beQwGlWUeUbyxn4Un5OE">[자유로운글(새싹 멤...]</span></div><span class="IcXP7mRiD50miFBaMmKX beQwGlWUeUbyxn4Un5OE"><mark>블로그</mark> 효과가 정말 크네요</span></div><div class="Q3XDmXBUSnsRZgPpEwIK idylRzgFhiSXk5gTlWnj"><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">3주 전</span><div class="pp_0VysqQ_HycljoTxin pwHV7Ne8t_6a_C3KLnig"></div><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">댓글 72</span></div></div></a><div class="pp_0VysqQ_HycljoTxin"></div><a nocr="1" href="http://cafe.naver.com/makegoodstudy/664258?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6Im1ha2Vnb29kc3R1ZHkiLCJhcnRpY2xlSWQiOjY2NDI1OCwiaXNzdWVkQXQiOjE3MzI1MDE0NDI5NTB9.83ATjLEL5ppm-shtv3YLDPogitM-I3jo41467hN17M8" class="DHukbqvLPOXU2MlU1a0g GxUmIoU8s2hAaEmbtMpE" target="_blank"><div class="aP5cLUcLjx_Fx9gMuOvQ idylRzgFhiSXk5gTlWnj"><div class="QRmos_1QilWZ3PjNpQwU idylRzgFhiSXk5gTlWnj"><div class="sDuQ8VNY0Y5EasY7sJMT PM5uqnnof_rRq83viDFg idylRzgFhiSXk5gTlWnj"><span class="pyY0f7u443HUSUqESW4C beQwGlWUeUbyxn4Un5OE">[자유로운글(새싹 멤...]</span></div><span class="IcXP7mRiD50miFBaMmKX beQwGlWUeUbyxn4Un5OE">자기<mark>블로그</mark>에서요?</span></div><div class="Q3XDmXBUSnsRZgPpEwIK idylRzgFhiSXk5gTlWnj"><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">3주 전</span><div class="pp_0VysqQ_HycljoTxin pwHV7Ne8t_6a_C3KLnig"></div><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">댓글 11</span></div></div></a></div></div></div><div class="jy_7bFnZxjKxnsZTqob2 idylRzgFhiSXk5gTlWnj" data-template-id="ugcCafeItem"><div class="KdXS4gty0h2yFULwxIbA idylRzgFhiSXk5gTlWnj"><a nocr="1" href="https://cafe.naver.com/jpnstory" class="DHukbqvLPOXU2MlU1a0g" target="_blank">
# <a nocr="1" href="https://cafe.naver.com/jpnstory" class="DHukbqvLPOXU2MlU1a0g EzNkJXXEnI4Z7V6swnFh" target="_blank">
# <a nocr="1" href="https://cafe.naver.com/jpnstory" class="DHukbqvLPOXU2MlU1a0g" target="_blank">
# <a nocr="1" href="http://cafe.naver.com/jpnstory/3790598?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImpwbnN0b3J5IiwiYXJ0aWNsZUlkIjozNzkwNTk4LCJpc3N1ZWRBdCI6MTczMjUwMTQ0Mjk1MH0.1Mo_FkUyBwuGdsAtK9wm6dqjbwxXeYgpoCERW0Q2WHk" class="DHukbqvLPOXU2MlU1a0g GxUmIoU8s2hAaEmbtMpE" target="_blank"><div class="aP5cLUcLjx_Fx9gMuOvQ idylRzgFhiSXk5gTlWnj"><div class="QRmos_1QilWZ3PjNpQwU idylRzgFhiSXk5gTlWnj"><div class="sDuQ8VNY0Y5EasY7sJMT PM5uqnnof_rRq83viDFg idylRzgFhiSXk5gTlWnj"><span class="pyY0f7u443HUSUqESW4C beQwGlWUeUbyxn4Un5OE">[수다방(여행질문금지...]</span></div><span class="IcXP7mRiD50miFBaMmKX beQwGlWUeUbyxn4Un5OE"><mark>블로그</mark> 다시 시작해야겠어용. ㅎㅎㅎ</span></div><div class="Q3XDmXBUSnsRZgPpEwIK idylRzgFhiSXk5gTlWnj"><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">1주 전</span><div class="pp_0VysqQ_HycljoTxin pwHV7Ne8t_6a_C3KLnig"></div><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">댓글 20</span></div></div></a><div class="pp_0VysqQ_HycljoTxin"></div><a nocr="1" href="http://cafe.naver.com/jpnstory/3774767?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImpwbnN0b3J5IiwiYXJ0aWNsZUlkIjozNzc0NzY3LCJpc3N1ZWRBdCI6MTczMjUwMTQ0Mjk1MH0.WsUh0SozghLHeIaTZ3TpnVbc-c7Au5qlgJ_pECCMD8E" class="DHukbqvLPOXU2MlU1a0g GxUmIoU8s2hAaEmbtMpE" target="_blank"><div class="aP5cLUcLjx_Fx9gMuOvQ idylRzgFhiSXk5gTlWnj"><div class="QRmos_1QilWZ3PjNpQwU idylRzgFhiSXk5gTlWnj"><div class="sDuQ8VNY0Y5EasY7sJMT PM5uqnnof_rRq83viDFg idylRzgFhiSXk5gTlWnj"><span class="pyY0f7u443HUSUqESW4C beQwGlWUeUbyxn4Un5OE">[수다방(여행질문금지...]</span></div><span class="IcXP7mRiD50miFBaMmKX beQwGlWUeUbyxn4Un5OE">일본인이 사용하는 <mark>블로그</mark>는 어떤게 있을까요??</span></div><div class="Q3XDmXBUSnsRZgPpEwIK idylRzgFhiSXk5gTlWnj"><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">3주 전</span><div class="pp_0VysqQ_HycljoTxin pwHV7Ne8t_6a_C3KLnig"></div><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">댓글 15</span></div></div></a></div></div></div></div><a href="#" role="button" class="mdAw5_v9T6i9u8GeyY9q MF9CDCPu__od7ATPFwpu" aria-expanded="false" data-template-id="expandButton"><div class="yp11ROO3_N_n55s4Sca8 jp7GqyymRzzjRa7XohXE"><span class="x5I9TxSxXjDMmbyXmSX3 beQwGlWUeUbyxn4Un5OE">펼쳐서 더보기</span><svg xmlns="http://www.w3.org/2000/svg" viewBox="0.5 0 13 8" class="NjIVSiJhTKguPeh9qHdD uuwzPfsjKq38px_rUKfx" width="13" height="8" fill="none"><title>펼쳐서 더보기</title><path class="TLj8ggWWE9dzqWSrnMy2" d="M12.9999 1L6.99988 7L0.999878 1"></path></svg></div></a></div></div></div><script>(function () { var startApplication = function () { var require = window.require.config({ "context": "fender_renderer_2c98db586b8584e0433b" }); require(["https://ssl.pstatic.net/sstatic/fe/fender/client/2c98db586b8584e0433b/index.js"], function (entry) { entry.bootstrap(document.getElementById("fdr-864e52dddace4da4bb5edf34a9d8536d"), {"appElementAttrs":{"data-slog-container":"ugB_ceR","class":"sc_new _slog_visible"},"rootElementAttrs":{"className":"api_subject_bx"},"meta":{"area":"ugB_ceR","nscs":"0","query":"블로그","ssc":"tab.nx.all","ssuid":"intentblock"},"refs":{"blockId":"ugc-cafe/prs_template_ugc_cafe_basic_desk.ts"},"body":{"props":{"children":[{"props":{"children":[{"props":{"className":"fds-title-basic","text":"블로그 정보가 많은 카페","type":"basic"},"templateId":"headerTitle"}]},"templateId":"header"},{"actionsMap":{"box":[{"props":{"clickEventName":"footer_click"},"templateId":"expandToggleAction"}]},"props":{"aria-expanded":false,"children":[{"props":{"articles":[{"categoryText":"[30대 수다방]","clickLog":{"item":{"element":".link","i":"90000004_009A07A3045EBAD000000000","r":0}},"commentCountText":"댓글 3","createdText":"2일 전","isNew":true,"link":"http://cafe.naver.com/imsanbu/73317072?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI ...
# <a href="?nso=&amp;page=2&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=2&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">
# <a href="?nso=&amp;page=3&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=3&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">
# <a href="?nso=&amp;page=4&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=4&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">
# <a href="?nso=&amp;page=5&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=5&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">
# <a href="?nso=&amp;page=6&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=6&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">
# <a href="?nso=&amp;page=7&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=7&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">
# <a href="?nso=&amp;page=8&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=8&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">
# <a href="?nso=&amp;page=9&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=9&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">
# <a href="?nso=&amp;page=10&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=121&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=10&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">10</a></div><a href="?nso=&amp;page=11&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=11&i=&u="+urlencode(this.href))' role="button" class="btn_next" aria-disabled="false"><i class="spnew api_ico_pg_arr">다음</i></a></div></div><div class="_scrollLogEndline" style="visibility:hidden;height:0px"></div></div><div id="sub_pack" class="sub_pack"><section class="sc_new"> <div class="api_subject_bx"> <div class="api_common_banner"> <a nocr onclick="return goOtherCR(this, 'a=bnr.link1&r=1&i=&u=' + urlencode(this.href));" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&campaign_id=2408-clovax-001&material=eraser&target=https%3A%2F%2Fclova-x.naver.com%2Fagent%2F2ZHp5sm8V5uUPu_gtqlT9.ai_object_remover%3Fdtm_detail%3Deraser%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2408-clovax-001" class="spnew_bf item" target="_blank"> <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20240804_24/1722783362661GGWtR_PNG/760_31963112_marketing_banner_pc_icon_0_1722783362643.png" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">AI로 사진 속 물체 지우기</strong> <p class="elss dsc">AI 지우개 CLOVA X</p> </div> </a> <a nocr onclick="return goOtherCR(this, 'a=bnr.link2&r=2&i=&u=' + urlencode(this.href));" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&campaign_id=2410-shopping-003&material=kv_black_2&target=https%3A%2F%2Fshopping.naver.com%2Fns%2Fhome%3Fdtm_detail%3Dkv_black_2%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2410-shopping-003" class="spnew_bf item" target="_blank"> <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20241030_130/1730274915701f2o17_PNG/760_31963112_marketing_banner_pc_icon_1_1730274915693.png" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">깎고+받고+쌓는 셈이 다른 쇼핑</strong> <p class="elss dsc">네이버플러스 스토어 오픈</p> </div> </a> <a nocr onclick="return goOtherCR(this, 'a=bnr.link3&r=3&i=&u=' + urlencode(this.href));" href="http://naver.me/xHgZCkuS" class="spnew_bf item" > <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20241117_246/1731854986148pU1ao_PNG/760_31963112_marketing_banner_pc_icon_2_1731854986141.png" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">가을의 맛과 멋이 가득한 곳</strong> <p class="elss dsc">요즘 뜨는 여행지 보러 가기</p> </div> </a> <a nocr onclick="return goOtherCR(this, 'a=bnr.link4&r=4&i=&u=' + urlencode(this.href));" href="https://mkt.naver.com/p1/atrb?channel_id=tongrightupper&campaign_id=2410-navermkt-001&target=https%3A%2F%2Fmkt.naver.com%2Fhiddenarchive%3Fdtm_source%3Dtongrightupper%26dtm_medium%3Dmktatrb%26dtm_campaign%3D2410-navermkt-001" class="spnew_bf item" target="_blank"> <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20241025_99/1729823429117tylgU_PNG/760_31963112_marketing_banner_pc_icon_3_1729823429110.png" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">20대가 찜한 핫플 모음 100+ </strong> <p class="elss dsc">장소와 취향의 발견, 히든 아카이브</p> </div> </a> </div> </div> </section> <script> var nx_cr_right_area_info = [{"n": "bnr", "r": 1}]; </script></div><div class="ly_dimmed"></div> </div><div class="mod_bridge_layer _sfe_layer_bridge_root" data-lb-render-type="pc" style="display: none"> <div class="_lb_init_target"> <div class="bridge_header"> <div class="bridge_dim _lb_header_dim"></div> <div class="header_wrap _lb_header_root"> <div class="header_area"> <div class="header_box _lb_header_box"> <a href="#" class="link_prev _lb_header_back_button"><i class="spnew api_ico_prev">이전</i> ...
