# %%
import requests
import re

# %%
url = "https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EB%B8%94%EB%A1%9C%EA%B7%B8"
response = requests.get(url)
html_text = response.text

# %%
print(html_text)
# Out:
# <!doctype html> <html lang="ko"><head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta property="og:title" content="블로그 : 네이버 검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="'블로그'의 네이버 검색 결과입니다."> <meta name="description" lang="ko" content="'블로그'의 네이버 검색 결과입니다."> <title>블로그 : 네이버 검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_32x32_240820.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><script> if (top.frames.length!=0 || window!=top) window.open(location, "_top"); </script><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_241121.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_241121.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_241031.css"><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; </script><script> naver = window.naver || {}; naver.search = naver.search || {}; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); function nx_add_event_handler (event, func) { $Fn(func).attach(document, event) ; } function bt(id, after) { document.getElementById(id).src = after; } function document_write (s) { document.write(s) ; } </script><script> var nx_au_cookie_domain = ".search.naver.com" ; var g_site = "" ; function nx_defer_eval (id) { var codeElement = document.getElementById(id), code = codeElement.innerHTML; eval(code.replace(/\/\*/, '').replace(/\*\//, '')); } function trim_crlf (q) { var crlf = /[\r|\n]/ ; q = q.replace(crlf, "") ; return q ; } function include_script (type, defer, src, charset) { var script = document.createElement("script") ; script.type = type, script.defer = defer ; script.src = src ; if (charset) script.charset = charset ; else script.charset = 'utf-8' ; document.getElementsByTagName('head')[0].appendChild(script) ; return script ; } function include_style (src, charset) { var h = document.getElementsByTagName("head")[0] ; var l = document.createElement('link') ; l.type = 'text/css' ; l.rel = 'stylesheet' ; if (charset) l.charset = charset ; else l.charset = 'utf-8' ; l.media = 'screen' ; l.href = src ; h.appendChild(l) ; } function rank_val (rank, name, sign, number, ad_onair) { this.rank = rank ; this.name = name ; this.sign = sign ; this.number = number ; this.ad_onair = ad_onair ; } function rr_hotquery_val (titleImg, totalLink, ad_onair) { this.titleImg = titleImg ; this.totalLink = totalLink ; this.ad_onair = ad_onair ; } function rr_append () { for (var i=0; i<rr_list.length; i++) if (rr_list[i].qname==hotqry_Name && rr_list[i].dir==hotqry_Dir) return 0 ; var o = { order:hotqry_Order, contid:hotqry_ContID, qname:hotqry_Name, dir:hotqry_Dir, toprank:hotqry_TopRank, rankdown:hotqry_RankDown, clicklog:hotqry_ClickLog, toprank_idx:toprank_idx, lowrank_idx:lowrank_idx, topranklist:toprank, lowranklist:lowrank_idx>=0?lowrank:null } ; rr_list = rr_list.concat(o) ; return 1 ; } var msg_hidden_idle=null; function msg (id) { if(msg_hidden_idle) clearInterval(msg_hidden_idle); if(id) { var mid=document.getElementById(id); mid.style.display=''; mid.style.visibility='visible'; } } function msg_hidden (id, f) { if(f) hidden(id); else msg_hidden_idle=setInterval("hidden('"+id+"')",100); } function hidden (id) { var mid=document.getElementById(id); mid.style.display='none'; mid.style.visibility ...
#           src="https://ssl.pstatic.net/adimg3.search/adpost/js/event_tracker.js?o=search"></script>
#   <script crossOrigin="anonymous" src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/js/231108/power_link_for_you_responsive_pc.js?o=search"></script>
#   <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl && _elAdIndLayerPl.visible()) {
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elAdIndLayerPl = _elDscNcautionPl.next().next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         _elAdIndLayerPl.hide();
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
#   <script>
#     (function () {
#       var defaultFavicon = "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png";
#       naver.common.imageLazyLoader.onError(
#               naver.common.LazySrc.Handler.create({
#                 "power-link-favicon-error": function ($img) {
#                   $img.attr("src", defaultFavicon);
#                 }
#               })
#       );
#     })();
#   </script>
#   <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/241115/css/nx_powerlink.css" rel="stylesheet" type="text/css">
#   <link rel="stylesheet" type="text/css"
#         href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css">
#   <div class="sc_new ad_section section _pl_section bg_type_v2">
#     <div class="api_subject_bx">
#       <div class="mod_title_area">
#         <div class="title_wrap">
#           <h2 class="title">파워링크</h2>
#           <span class="sub">
#             <span class="title_text">
#               <em class="dsc_ncaution_quotation">‘</em>
#               <strong class="dsc_ncaution_keyword">블로그</strong>
#               <em class="dsc_ncaution_quotation">’</em>관련 광고입니다.
#             </span>
#           </span>
#           <a href="javascript:void(0);" role="button" class="api_ad_link" onclick="if(adInfoShowPl(this)) goOtherCR(this, &#39;a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u=&#39;+urlencode(this.href));">
#             <i class="spnew api_ico_alert">이 광고가 표시된 이유</i>
#           </a>
#         </div>
#         <div class="title_sub">
#           <a href="//saedu.naver.com/adbiz/searchad/clickChoice.naver" class="sub_link" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u=&#39;+urlencode(this.href));"
#           >등록 안내</a>
#         </div>
#         <div class="ly_api_info" style="display: none;">
#           <p class="dsc">이 광고는 사이트검색광고(파워링크)로, 검색어와 광고의 연관도, 광고주의 입찰가 등에 의해 광고 노출 여부와 순위가 결정됩니다.</p>
#           <div class="btn_area">
#             <a href="https://help.naver.com/service/5626/contents/1419" class="link">도움말</a>
#           </div>
#           <button type="button" class="btn_close" onclick="adInfoHidePl();">
#             <i class="spnew ico_close">정보확인 레이어 닫기</i>
#           </button>
#         </div>
#       </div>
#       <div class="nad_area" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=V-1RHS4ciZVp9EXBo5jSEuOwlHHdkS-...">
#         <ul class="lst_type">
#           <li class="lst type_more type_subtitle ext_link   type_img  "
#               onMouseOver="jindo.$Element(this).addClass('ad_hover');"
#               onMouseOut="jindo.$Element(this).removeClass('ad_hover');" num="0">
#             <a class="lnk_thumb"
#                href="https://adcr.naver.com/adcr?x=VvPO+/c+o/WRFD6NKb/Fsv///w==..."
#                target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#               <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMjAxMDZfMjYz/MDAxNjQxNDU1ODk1ODAy.oUkSIc_pZrIQApxPGzyEw9v3HPyHTEYrTA4sBteBEkcg.gs2ZPEDXfrDjII1ztVHm3yNDhfCnKi7xcpHGSFMowJUg.JPEG/698519-10d8930c-1b4a-42c9-a3bb-a748c8107e18.jpg?type=f160_160">
#             </a>
#             <div class="inner">
#               <div class="title_url_area">
#                 <div class="url_area">
#                   <a href="https://adcr.naver.com/adcr?x=97V+1076neXl0unsMyWOTf///w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <img width="16" height="16" alt="favicon" class="icon_favicon"
#                          data-img-alias="power-link-favicon-error"
#                          data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fbiz.revu.net%2Frevu-favicon.ico&amp;type=f30_30_png_expire24"
#                          src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png">
#                   </a>
#                   <span class="icon_nad_mark">광고</span>
#
#                   <a href="https://adcr.naver.com/adcr?x=97V+1076neXl0unsMyWOTf///w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">레뷰</a>
#                   <span class="lnk_url_area">
#                     <a href="https://adcr.naver.com/adcr?x=97V+1076neXl0unsMyWOTf///w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">biz.revu.net/</a>
#                   </span>
#                 </div>
#                 <a href="https://adcr.naver.com/adcr?x=97V+1076neXl0unsMyWOTf///w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39; + urlencode(&#39;https://biz.revu.net/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#
#
#
#                       <span class="lnk_tit"><strong class='hl'>블로그</strong> 전문, 레뷰</span><span
#                             class="lnk_tit">870만 업계최다 성공사례</span>
#
#
#
#                 </a>
#               </div>
#
#
#
#               <div class="desc_area">
#
#
#
#                   <a href="https://adcr.naver.com/adcr?x=97V+1076neXl0unsMyWOTf///w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39; + urlencode(&#39;https://biz.revu.net/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">120만 진짜 인플루언서 매칭! 원고검수 시스템으로 콘텐츠 퀄리티 100% 보장!</a>
#
#
#               </div>
#
#               <ul class="lst_link">
#
#                   <li class="item">
#                     <a class="link" href="https://adcr.naver.com/adcr?x=LFhGh8h7PIMiwWbmq9Ev1////w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">가게마케팅</a>
#                   </li>
#
#                   <li class="item">
#                     <a class="link" href="https://adcr.naver.com/adcr?x=8Ng7tCXtgssDMiF5tKrSS////w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">상품마케팅</a>
#                   </li>
#
#                   <li class="item">
#                     <a class="link" href="https://adcr.naver.com/adcr?x=KsXnG4MWfVEjWz2g1ylAb////w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">대행사문의</a>
#                   </li>
#
#                   <li class="item">
#                     <a class="link" href="https://adcr.naver.com/adcr?x=xI89LKyj9harqJ8Iq3qOUv///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink4&amp;r=1&amp;i=nad-a001-01-000000333872661&amp;d=&#39;+urlencode(&#39;https://biz.revu.net/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">글로벌마케팅</a>
#                   </li>
#
#               </ul>
#
#
#
#
#             </div>
#           </li>
#           <li class="lst type_more     type_img  "
#               onMouseOver="jindo.$Element(this).addClass('ad_hover');"
#               onMouseOut="jindo.$Element(this).removeClass('ad_hover');" num="1">
#             <a class="lnk_thumb"
#                href="https://adcr.naver.com/adcr?x=z6M+uwpCl6oPKe2F4WkE8////w==..."
#                target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39;+urlencode(&#39;http://stormdayz.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#               <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAxOTA1MTdfMTQ0/MDAxNTU4MDU0MTk3MDk0.fZ-6uT8zFQqVcqZAM3gOsDMsWCC8y9kIf57rWtfU-7sg.7x6aqJr7Vt_ctHy940sV2pAraRPpLTFx0OPoS83s6lAg.JPEG/657843-41cbac80-9947-4ac8-931f-c0790f1abf21.jpg?type=f160_160">
#             </a>
#             <div class="inner">
#               <div class="title_url_area">
#                 <div class="url_area">
#                   <a href="https://adcr.naver.com/adcr?x=iiQm3ZjcEHIRsUfdH2b+5////w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39;+urlencode(&#39;http://stormdayz.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <img width="16" height="16" alt="favicon" class="icon_favicon"
#                          data-img-alias="power-link-favicon-error"
#                          data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fcdn.imweb.me%2Fthumbnail%2F20230202%2F02ff781ec61a7.png&amp;type=f30_30_png_expire24"
#                          src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png">
#                   </a>
#                   <span class="icon_nad_mark">광고</span>
#
#                   <a href="https://adcr.naver.com/adcr?x=iiQm3ZjcEHIRsUfdH2b+5////w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39;+urlencode(&#39;http://stormdayz.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">스톰데이즈</a>
#                   <span class="lnk_url_area">
#                     <a href="https://adcr.naver.com/adcr?x=iiQm3ZjcEHIRsUfdH2b+5////w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39;+urlencode(&#39;http://stormdayz.com&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">stormdayz.com</a>
#                   </span>
#                 </div>
#                 <a href="https://adcr.naver.com/adcr?x=iiQm3ZjcEHIRsUfdH2b+5////w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39; + urlencode(&#39;http://stormdayz.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#
#
#
#
#                       <span class="lnk_tit"><strong class='hl'>블로그</strong>디자인제작 스톰데이즈</span>
#
#
#                 </a>
#               </div>
#
#
#
#               <div class="desc_area">
#
#
#
#                   <a href="https://adcr.naver.com/adcr?x=iiQm3ZjcEHIRsUfdH2b+5////w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=2&amp;i=nad-a001-01-000000325562396&amp;d=&#39; + urlencode(&#39;http://stormdayz.com&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));"><strong class='hl'>블로그</strong> 디자인제작 전문, <strong class='hl'>블로그</strong>제작대행, <strong class='hl'>블로그</strong>꾸미기, 마케팅을 위한 디자인</a>
#
#
#               </div>
#
#
#
#
#
#
#             </div>
#           </li>
#           <li class="lst type_more type_subtitle ext_link   type_img  "
#               onMouseOver="jindo.$Element(this).addClass('ad_hover');"
#               onMouseOut="jindo.$Element(this).removeClass('ad_hover');" num="2">
#             <a class="lnk_thumb"
#                href="https://adcr.naver.com/adcr?x=Nud7cV5ayBqGacOwwmpkwf///w==..."
#                target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#               <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAxOTAyMjdfMjc0/MDAxNTUxMjQxNjAwOTU4.hBMqGu01NdosJaBkZT0sZZgF0HduCHvpn_wUyORy4i0g.oU1DjBpFicitGRYkDvmSJfcGOmA2-qNL3iahdbzQwbUg.JPEG/854674-d1397531-9919-4c23-924e-2541ff0020ad.JPG?type=f160_160">
#             </a>
#             <div class="inner">
#               <div class="title_url_area">
#                 <div class="url_area">
#                   <a href="https://adcr.naver.com/adcr?x=KTpNk5Uevou4VJrOXJ8fIv///w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <img width="16" height="16" alt="favicon" class="icon_favicon"
#                          data-img-alias="power-link-favicon-error"
#                          data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fimg-shop.pstatic.net%2Ffront%2Fnaver_favicon.ico&amp;type=f30_30_png_expire24"
#                          src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png">
#                   </a>
#                   <span class="icon_nad_mark">광고</span>
#                   <span class="ico_area">
#
#                     <span class="ico">
#                       <button class="sp_nad ico_npay_plus"
#                             alt="네이버페이"
#                             onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                             onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                             onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                             onBlur="NAVER.SEARCH_AD.hideTooltip(this);"><span class="blind">네이버페이</span></button>
#                       <a href="https://m.pay.naver.com/mobile/about" target="_blank" class="ly_ad _tooltip"
#                          style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                          onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                          onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                          onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.checkout&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;u=&#39;+urlencode(this.href));">
#                         <span class="ly_box">
#                           <span>네이버 아이디 하나로 간편구매</span>
#                           <span class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_nad bu"></span></span>
#                         </span>
#                       </a>
#                     </span>
#
#
#
#                   </span>
#                   <a href="https://adcr.naver.com/adcr?x=KTpNk5Uevou4VJrOXJ8fIv///w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000304926479&amp;d=&#39;+urlencode(&#39;https://smartstore.naver.com/modoomkt&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));
Focus="NAVER.SEARCH_AD.showTooltip(this);"
#                             onBlur="NAVER.SEARCH_AD.hideTooltip(this);"><span class="blind">네이버 로그인</span></button>
#                       <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" class="ly_ad _tooltip"
#                          style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                          onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                          onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                          onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;u=&#39;+urlencode(this.href));">
#                         <span class="ly_box">
#                           <span>네이버 아이디로 로그인이 가능합니다.</span>
#                           <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
#                         </span>
#                       </a>
#                     </span>
#
#
#                   </span>
#                   <a href="https://adcr.naver.com/adcr?x=1sBd75UsquOfR83znv1/4P///w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">리뷰플레이스</a>
#                   <span class="lnk_url_area">
#                     <a href="https://adcr.naver.com/adcr?x=1sBd75UsquOfR83znv1/4P///w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">reviewplace.co.kr/</a>
#                   </span>
#                 </div>
#                 <a href="https://adcr.naver.com/adcr?x=1sBd75UsquOfR83znv1/4P///w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39; + urlencode(&#39;http://www.reviewplace.co.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#
#
#
#                       <span class="lnk_tit">확실한 체험단, 리뷰플레이스</span><span
#                             class="lnk_tit">인당 1만원대</span><span
#                             class="lnk_tit">첫광고주 특별가</span>
#
#
#
#                 </a>
#               </div>
#
#
#
#               <div class="desc_area">
#
#
#
#                   <a href="https://adcr.naver.com/adcr?x=1sBd75UsquOfR83znv1/4P///w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39; + urlencode(&#39;http://www.reviewplace.co.kr/&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">98만 리뷰어! 네이버 로직분석 및 전략적세팅으로 매출에 도움되는 광고 진행하세요</a>
#
#
#               </div>
#
#               <ul class="lst_link">
#
#                   <li class="item">
#                     <a class="link" href="https://adcr.naver.com/adcr?x=XB5jtxxAZEQJ6NujiA5eOf///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink1&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">업종레퍼런스</a>
#                   </li>
#
#                   <li class="item">
#                     <a class="link" href="https://adcr.naver.com/adcr?x=SbkUWYNCYtFpBfmt9M2ArP///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink2&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">제안서받기</a>
#                   </li>
#
#                   <li class="item">
#                     <a class="link" href="https://adcr.naver.com/adcr?x=GnotzKH/FeDiclTc9Pk9sv///w==..."
#                        target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.sublink3&amp;r=5&amp;i=nad-a001-01-000000270363867&amp;d=&#39;+urlencode(&#39;http://www.reviewplace.co.kr/&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">무료상담</a>
#                   </li>
#
#               </ul>
#
#
#
#
#             </div>
#           </li>
#           <li class="lst type_more     type_img  "
#               onMouseOver="jindo.$Element(this).addClass('ad_hover');"
#               onMouseOut="jindo.$Element(this).removeClass('ad_hover');" num="5">
#             <a class="lnk_thumb"
#                href="https://adcr.naver.com/adcr?x=9LcqWFKIccTZrOa3u3mwsv///w==..."
#                target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.image&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39;+urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#               <img alt="링크이미지" class="img_thumb" src="https://searchad-phinf.pstatic.net/MjAyMDA1MjBfNjQg/MDAxNTg5OTQyNjM4ODU5.XohNB7wvZT82LkPD7WR-sjgyz2dlGWdQyM6R9cg-qbog.Cjkb5SYZo5p6cOvRBDeREgzHl3h9wzqE9I3lVtZqP4wg.JPEG/369412-ede8a016-8cbf-438d-a9e2-83db217a39cf.JPG?type=f160_160">
#             </a>
#             <div class="inner">
#               <div class="title_url_area">
#                 <div class="url_area">
#                   <a href="https://adcr.naver.com/adcr?x=EksPrq84gKul4Gi96LVtFP///w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39;+urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <img width="16" height="16" alt="favicon" class="icon_favicon"
#                          data-img-alias="power-link-favicon-error"
#                          data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fsmkt.co.kr%2Fimages%2Fsmkt.ico&amp;type=f30_30_png_expire24"
#                          src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png">
#                   </a>
#                   <span class="icon_nad_mark">광고</span>
#
#                   <a href="https://adcr.naver.com/adcr?x=EksPrq84gKul4Gi96LVtFP///w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39;+urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">스마트마케팅인포</a>
#                   <span class="lnk_url_area">
#                     <a href="https://adcr.naver.com/adcr?x=EksPrq84gKul4Gi96LVtFP///w==...&amp;p=1"
#                        class="lnk_url" target="_blank"
#                        onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39;+urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">smkt.co.kr/ad/</a>
#                   </span>
#                 </div>
#                 <a href="https://adcr.naver.com/adcr?x=EksPrq84gKul4Gi96LVtFP///w==...&amp;p=0" class="lnk_head" target="_blank" onclick="return goOtherCR(this, &#39;a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39; + urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));">
#
#
#
#
#                       <span class="lnk_tit">매출이 오르는 스마트마케팅</span>
#
#
#                 </a>
#               </div>
#
#
#
#               <div class="desc_area">
#
#
#
#                   <a href="https://adcr.naver.com/adcr?x=EksPrq84gKul4Gi96LVtFP///w==..." class="link_desc" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.desc&amp;r=6&amp;i=nad-a001-01-000000112320402&amp;d=&#39; + urlencode(&#39;https://www.smkt.co.kr/ad/?cc=smktkinginfo&#39;) + &#39;&amp;u=&#39;+ urlencode(this.href));"><strong class='hl'>블로그</strong> 매출이 오르는 마케팅의 절 대 강 자 스마트마케팅 차원이 다른 컨설팅</a>
#
#
#               </div>
#
#
#
#
#
#
#             </div>
#           </li>
#           <li class="lst type_more type_subtitle      "
#               onMouseOver="jindo.$Element(this).addClass('ad_hover');"
#               onMouseOut="jindo.$Element(this).removeClass('ad_hover');" num="6">
#
#             <div class="inner">
#               <div class="title_url_area">
#                 <div class="url_area">
#                   <a href="https://adcr.naver.com/adcr?x=Ehoo9ydLOtQcN+0uOQfslv///w==..." class="favicon_wrap" target="_blank" onclick="return goOtherCR(this,&#39;a=pwl_nop.favicon&amp;r=7&amp;i=nad-a001-01-000000296906665&amp;d=&#39;+urlencode(&#39;http://www.gmarket.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">
#                     <img width="16" height="16" alt="favicon" class="icon_favicon"
#                          data-img-alias="power-link-favicon-error"
#                          data-lazysrc="https://search.pstatic.net/sunny?src=https%3A%2F%2Fimage.gmarket.co.kr%2Ffavicon%2Fgmarket.ico&amp;type=f30_30_png_expire24"
#                          src="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230719/img/icon_favicon.png">
#                   </a>
#                   <span class="icon_nad_mark">광고</span>
#                   <span class="ico_area">
#
#
#                     <span class="ico">
#                       <button class="sp_nad ico_nlogin"
#                             onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                             onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);"
#                             onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                             onBlur="NAVER.SEARCH_AD.hideTooltip(this);"><span class="blind">네이버 로그인</span></button>
#                       <a href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" class="ly_ad _tooltip"
#                          style="display:none" onFocus="NAVER.SEARCH_AD.showTooltip(this);"
#                          onBlur="NAVER.SEARCH_AD.hideTooltip(this);"
#                          onMouseOver="NAVER.SEARCH_AD.showTooltip(this);"
#                          onMouseOut="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, &#39;a=pwl_nop.naverlogin&amp;r=7&amp;i=nad-a001-01-000000296906665&amp;u=&#39;+urlencode(this.href));">
#                         <span class="ly_box">
#                           <span>네이버 아이디로 로그인이 가능합니다.</span>
#                           <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
#                         </span>
#                       </a>
#                     </span>
#
#
#                   </span>
#                   <a href="https://adcr.naver.com/adcr?x=Ehoo9ydLOtQcN+0uOQfslv///w==...&amp;p=1"
#                      class="site" target="_blank"
#                      onclick="return goOtherCR(this, &#39;a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000296906665&amp;d=&#39;+urlencode(&#39;http://www.gmarket.co.kr&#39;)+&#39;&amp;u=&#39;+urlencode(this.href));">G마켓</a>
#                   <span class="lnk_url_area">
#                     <a href="https://adcr.naver.com/adcr?x
fill="none" xmlns="http://www.w3.org/2000/svg">
# <path fill-rule="evenodd" clip-rule="evenodd" d="M1.5 0H18.5C19.3285 0 20 0.6715 20 1.5V9.395C20 11.048 18.983 12.5305 17.441 13.126L10.801 15.691C10.2855 15.89 9.7145 15.89 9.1995 15.691L2.559 13.126C1.017 12.531 0 11.048 0 9.395V1.5C0 0.6715 0.6715 0 1.5 0Z" fill="#03C75A"></path>
# <path fill-rule="evenodd" clip-rule="evenodd" d="M9.4465 3V10.511H8.186V6.839H7.7175V10.194H6.4825V3.1085H7.7175V5.754H8.186V3H9.4465ZM12.9125 7.444V8.6375H14.1215V7.444H15.467V8.6375H17V9.7465H10.0685V8.6375H11.5755V7.444H12.9125ZM5.93 3.843V4.878H4.3285V7.8655C4.9925 7.8655 5.691 7.7985 6.1085 7.707L6.202 8.75C5.606 8.9 4.337 8.95 3.622 8.942L3 8.9335V3.843H5.93ZM16.379 3.447V4.5595L14.4545 4.559L15.6635 4.681L15.4505 5.958H16.345V7.0765H10.673V5.958H11.6095L11.4565 4.639L12.604 4.559H10.6475V3.447H16.379ZM14.334 4.559H12.777L12.862 5.958H14.2245L14.334 4.559Z"></path>
# </svg></div><span class="BPqHDkyl8xhCTUTwZR49 beQwGlWUeUbyxn4Un5OE">네일동 : 일본여행카페</span></div><div class="gu6W8ie2Styys_U7TBtJ idylRzgFhiSXk5gTlWnj"><span class="gIiFEMGzVAWFg99e7Jhd beQwGlWUeUbyxn4Un5OE">멤버수 1,863,297</span><div class="pp_0VysqQ_HycljoTxin pwHV7Ne8t_6a_C3KLnig"></div><span class="gIiFEMGzVAWFg99e7Jhd beQwGlWUeUbyxn4Un5OE">새글 998</span></div></div></a><a nocr="1" href="https://cafe.naver.com/jpnstory" class="DHukbqvLPOXU2MlU1a0g" target="_blank"><svg class="bYQd_1wMEVi6GGi9BApZ" width="28" height="52" viewBox="0 0 28 52" fill="none" xmlns="http://www.w3.org/2000/svg">
# <g clip-path="url(#clip0_29_1683)">
# <circle cx="14" cy="26" r="14"></circle>
# <path d="M12.5 22L16.5 26L12.5 30"></path>
# </g>
# <defs>
# <clippath id="clip0_29_1683">
# <rect width="28" height="28" fill="white" transform="translate(0 12)"></rect>
# </clippath>
# </defs>
# </svg></a></div><div class="E4jNBv0k2nFvTlsOlMdv idylRzgFhiSXk5gTlWnj"><div class="_ObSScti0qNWfQzKHWDu idylRzgFhiSXk5gTlWnj"><a nocr="1" href="http://cafe.naver.com/jpnstory/3790598?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImpwbnN0b3J5IiwiYXJ0aWNsZUlkIjozNzkwNTk4LCJpc3N1ZWRBdCI6MTczMjQ5ODYzODkyN30.sguXnSnJB0o8qKdOTi9MU9Ij3Wsp8l9chankKkBcEC8" class="DHukbqvLPOXU2MlU1a0g GxUmIoU8s2hAaEmbtMpE" target="_blank"><div class="aP5cLUcLjx_Fx9gMuOvQ idylRzgFhiSXk5gTlWnj"><div class="QRmos_1QilWZ3PjNpQwU idylRzgFhiSXk5gTlWnj"><div class="sDuQ8VNY0Y5EasY7sJMT PM5uqnnof_rRq83viDFg idylRzgFhiSXk5gTlWnj"><span class="pyY0f7u443HUSUqESW4C beQwGlWUeUbyxn4Un5OE">[수다방(여행질문금지...]</span></div><span class="IcXP7mRiD50miFBaMmKX beQwGlWUeUbyxn4Un5OE"><mark>블로그</mark> 다시 시작해야겠어용. ㅎㅎㅎ</span></div><div class="Q3XDmXBUSnsRZgPpEwIK idylRzgFhiSXk5gTlWnj"><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">1주 전</span><div class="pp_0VysqQ_HycljoTxin pwHV7Ne8t_6a_C3KLnig"></div><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">댓글 20</span></div></div></a><div class="pp_0VysqQ_HycljoTxin"></div><a nocr="1" href="http://cafe.naver.com/jpnstory/3774767?art=ZXh0ZXJuYWwtc2VydmljZS1uYXZlci1zZWFyY2gtaW50ZW50LXZpZXc=.eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiY2FmZVVybCI6ImpwbnN0b3J5IiwiYXJ0aWNsZUlkIjozNzc0NzY3LCJpc3N1ZWRBdCI6MTczMjQ5ODYzODkyN30.X8IfVRzD6r7lcu2fv4bxhYzOofyH_MIh29NImTkOmhE" class="DHukbqvLPOXU2MlU1a0g GxUmIoU8s2hAaEmbtMpE" target="_blank"><div class="aP5cLUcLjx_Fx9gMuOvQ idylRzgFhiSXk5gTlWnj"><div class="QRmos_1QilWZ3PjNpQwU idylRzgFhiSXk5gTlWnj"><div class="sDuQ8VNY0Y5EasY7sJMT PM5uqnnof_rRq83viDFg idylRzgFhiSXk5gTlWnj"><span class="pyY0f7u443HUSUqESW4C beQwGlWUeUbyxn4Un5OE">[수다방(여행질문금지...]</span></div><span class="IcXP7mRiD50miFBaMmKX beQwGlWUeUbyxn4Un5OE">일본인이 사용하는 <mark>블로그</mark>는 어떤게 있을까요??</span></div><div class="Q3XDmXBUSnsRZgPpEwIK idylRzgFhiSXk5gTlWnj"><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">3주 전</span><div class="pp_0VysqQ_HycljoTxin pwHV7Ne8t_6a_C3KLnig"></div><span class="pvY2ouk7sMlW8WVm1SlP beQwGlWUeUbyxn4Un5OE">댓글 15</span></div></div></a></div></div></div></div><a href="#" role="button" class="mdAw5_v9T6i9u8GeyY9q MF9CDCPu__od7ATPFwpu" aria-expanded="false" data-template-id="expandButton"><div class="yp11ROO3_N_n55s4Sca8 jp7GqyymRzzjRa7XohXE"><span class="x5I9TxSxXjDMmbyXmSX3 beQwGlWUeUbyxn4Un5OE">펼쳐서 더보기</span><svg xmlns="http://www.w3.org/2000/svg" viewBox="0.5 0 13 8" class="NjIVSiJhTKguPeh9qHdD uuwzPfsjKq38px_rUKfx" width="13" height="8" fill="none"><title>펼쳐서 더보기</title><path class="TLj8ggWWE9dzqWSrnMy2" d="M12.9999 1L6.99988 7L0.999878 1"></path></svg></div></a></div></div></div><script>(function () { var startApplication = function () { var require = window.require.config({ "context": "fender_renderer_2c98db586b8584e0433b" }); require(["https://ssl.pstatic.net/sstatic/fe/fender/client/2c98db586b8584e0433b/index.js"], function (entry) { entry.bootstrap(document.getElementById("fdr-b6dc28ed51904371ada84546b4159823"), {"appElementAttrs":{"data-slog-container":"ugB_ceR","class":"sc_new _slog_visible"},"rootElementAttrs":{"className":"api_subject_bx"},"meta":{"area":"ugB_ceR","nscs":"0","query":"블로그","ssc":"tab.nx.all","ssuid":"intentblock"},"refs":{"blockId":"ugc-cafe/prs_template_ugc_cafe_basic_desk.ts"},"body":{"props":{"children":[{"props":{"children":[{"props":{"className":"fds-title-basic","text":"블로그 정보가 많은 카페","type":"basic"},"templateId":"headerTitle"}]},"templateId":"header"},{"actionsMap":{"box":[{"props":{"clickEventName":"footer_click"},"templateId":"expandToggleAction"}]},"props":{"aria-expanded":false,"children":[{"props":{"articles":[{"categoryText":"[30대 수다방]","clickLog":{"item":{"element":".link","i":"90000004_009A07A3045EBAD000000000","r":0}},"commentCountText":"댓글 3","createdText":"2일 전","isNew":true,"link":"http://cafe.naver.com/imsanbu/73317072?art=ZXh0ZXJuYWw ...
# <a href="?nso=&amp;page=2&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=2&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">2</a>
# <a href="?nso=&amp;page=3&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=3&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">3</a>
# <a href="?nso=&amp;page=4&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=4&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">4</a>
# <a href="?nso=&amp;page=5&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=5&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">5</a>
# <a href="?nso=&amp;page=6&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=6&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">6</a>
# <a href="?nso=&amp;page=7&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=7&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">7</a>
# <a href="?nso=&amp;page=8&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=8&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">8</a>
# <a href="?nso=&amp;page=9&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=9&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">9</a>
# <a href="?nso=&amp;page=10&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=121&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=10&i=&u="+urlencode(this.href))' role="button" class="btn" aria-pressed="false">10</a></div><a href="?nso=&amp;page=11&amp;query=%EB%B8%94%EB%A1%9C%EA%B7%B8&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick='goOtherCR(this,"a=pag.pag&r=11&i=&u="+urlencode(this.href))' role="button" class="btn_next" aria-disabled="false"><i class="spnew api_ico_pg_arr">다음</i></a></div></div><div class="_scrollLogEndline" style="visibility:hidden;height:0px"></div></div><div id="sub_pack" class="sub_pack"><section class="sc_new"> <div class="api_subject_bx"> <div class="api_common_banner"> <a nocr onclick="return goOtherCR(this, 'a=bnr.link1&r=1&i=&u=' + urlencode(this.href));" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&campaign_id=2408-clovax-001&material=eraser&target=https%3A%2F%2Fclova-x.naver.com%2Fagent%2F2ZHp5sm8V5uUPu_gtqlT9.ai_object_remover%3Fdtm_detail%3Deraser%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2408-clovax-001" class="spnew_bf item" target="_blank"> <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20240804_24/1722783362661GGWtR_PNG/760_31963112_marketing_banner_pc_icon_0_1722783362643.png" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">AI로 사진 속 물체 지우기</strong> <p class="elss dsc">AI 지우개 CLOVA X</p> </div> </a> <a nocr onclick="return goOtherCR(this, 'a=bnr.link2&r=2&i=&u=' + urlencode(this.href));" href="https://mkt.naver.com/p1/atrb?channel_id=naver_pcsearchmktbanner&campaign_id=2410-shopping-003&material=kv_black_2&target=https%3A%2F%2Fshopping.naver.com%2Fns%2Fhome%3Fdtm_detail%3Dkv_black_2%26dtm_source%3Dnaver_pcsearchmktbanner%26dtm_medium%3Dmktatrb_etc%26dtm_campaign%3D2410-shopping-003" class="spnew_bf item" target="_blank"> <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20241030_130/1730274915701f2o17_PNG/760_31963112_marketing_banner_pc_icon_1_1730274915693.png" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">깎고+받고+쌓는 셈이 다른 쇼핑</strong> <p class="elss dsc">네이버플러스 스토어 오픈</p> </div> </a> <a nocr onclick="return goOtherCR(this, 'a=bnr.link3&r=3&i=&u=' + urlencode(this.href));" href="http://naver.me/xHgZCkuS" class="spnew_bf item" > <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20241117_246/1731854986148pU1ao_PNG/760_31963112_marketing_banner_pc_icon_2_1731854986141.png" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">가을의 맛과 멋이 가득한 곳</strong> <p class="elss dsc">요즘 뜨는 여행지 보러 가기</p> </div> </a> <a nocr onclick="return goOtherCR(this, 'a=bnr.link4&r=4&i=&u=' + urlencode(this.href));" href="https://mkt.naver.com/p1/atrb?channel_id=tongrightupper&campaign_id=2410-navermkt-001&target=https%3A%2F%2Fmkt.naver.com%2Fhiddenarchive%3Fdtm_source%3Dtongrightupper%26dtm_medium%3Dmktatrb%26dtm_campaign%3D2410-navermkt-001" class="spnew_bf item" target="_blank"> <div class="ico_area"><img src="https://csearch-phinf.pstatic.net/20241025_99/1729823429117tylgU_PNG/760_31963112_marketing_banner_pc_icon_3_1729823429110.png" width="36" height="36" alt="" class="ico"></div> <div class="dsc_area"> <strong class="elss tit">20대가 찜한 핫플 모음 100+ </strong> <p class="elss dsc">장소와 취향의 발견, 히든 아카이브</p> </div> </a> </div> </div> </section> <script> var nx_cr_right_area_info = [{"n": "bnr", "r": 1}]; </script></div><div class="ly_dimmed"></div> </div><div class="mod_bridge_layer _sfe_layer_bridge_root" data-lb-render-type="pc" style="display: none"> <div class="_lb_init_target"> <div class="bridge_header"> <div class="bridge_dim _lb_header_dim"></div> <div class="header_wrap _lb_header_root"> <div class="header_area"> <div class="header_box _lb_header_box"> <a href="#" class="link_prev _lb_header_back_button"><i class="spnew api_ico_prev">이전</i> ...

# %%
pattern = r"<img.*src=['\"]([^'\"]*)['\"][^>]*>"
p = re.compile(pattern, re.I) # re.I == re.IGNORECASE
itr = p.finditer(html_text)

# %%
for m in itr:
    # print(m.group())
    print(m.group(1))
# Out:
# https://searchad-phinf.pstatic.net/MjAyMjAxMDZfMjYz/MDAxNjQxNDU1ODk1ODAy.oUkSIc_pZrIQApxPGzyEw9v3HPyHTEYrTA4sBteBEkcg.gs2ZPEDXfrDjII1ztVHm3yNDhfCnKi7xcpHGSFMowJUg.JPEG/698519-10d8930c-1b4a-42c9-a3bb-a748c8107e18.jpg?type=f160_160
