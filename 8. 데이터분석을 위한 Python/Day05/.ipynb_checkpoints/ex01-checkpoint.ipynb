# %%
try : # 예외가 발생할 가능성이 있는 코드 구간
    num1 = 10
    num2 = 0
    result = num1 / num2
    print(result)
except : # 예외에 대한 처리 구간
    print("예외 발생")

print("매우 중요한 코드! 꼭 실행되어야 함")
# Out:
# 예외 발생
# 매우 중요한 코드! 꼭 실행되어야 함

# %%
try : # 예외가 발생할 가능성이 있는 코드 구간
    num1 = 10
    num2 = 0
    result = num1 / num2
    print(result)
except ZeroDivisionError: # 0으로 나눴을 때에 대한 예외 처리 구간
    print("예외 발생")

print("매우 중요한 코드! 꼭 실행되어야 함")
# Out:
# 예외 발생
# 매우 중요한 코드! 꼭 실행되어야 함

# %%
try : # 예외가 발생할 가능성이 있는 코드 구간
    num1 = 10
    # num2 = 0
    num2 = 2
    result = num1 / num2
    print(result)

    fruits = ['사과', '멜론', '오렌지']
    # pos = fruits.index('망고') # 못 찾으면 예외처리
    # pos = fruits.find('망고') # 못 찾으면 -1 반환
    # print(pos)
# except ZeroDivisionError: # 0으로 나눴을 때에 대한 예외 처리 구간
    # print("0으로 나눴을 때 예외 발생")
# except ValueError:
    # print("value에 대한 예외 발생")
# except (ZeroDivisionError, ValueError):
    # print("예외 발생")
except Exception: # 다형성
    print("예외 발생")
else: # 예외가 발생하지 않으면 실행되는 구간
    print("잘 처리됨...")

print("매우 중요한 코드! 꼭 실행되어야 함")
# Out:
# 5.0
# 잘 처리됨...
# 매우 중요한 코드! 꼭 실행되어야 함

# %%
import traceback
try : # 예외가 발생할 가능성이 있는 코드 구간
    num1 = 10
    # num2 = 0
    num2 = 2
    result = num1 / num2
    print(result)

    fruits = ['사과', '멜론', '오렌지']
    pos = fruits.index('망고')
    print(pos)
    print(result)
except ZeroDivisionError as e: # 0으로 나눴을 때에 대한 예외 처리 구간, e : 발생한 예외 객체 참조 변수
    # print("예외 발생")
    print(e) # 발생한 예외 객체 정보 출력
    print(traceback.format_exc()) # 예외 발생에 대한 자세한 처리
except ValueError as e: # Value에 대한 예외처리 구간 , e : 발생한 예외 객체 참조 변수
    # print("value에 대한 예외 발생")
    print(e)
    print(traceback.format_exc()) # 예외 발생에 대한 자세한 처리

print("매우 중요한 코드! 꼭 실행되어야 함")
# Out:
# 5.0
# '망고' is not in list
# Traceback (most recent call last):
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_10784\4188095049.py", line 10, in <module>
#     pos = fruits.index('망고')
#           ^^^^^^^^^^^^^^^^^^^^
# ValueError: '망고' is not in list
#
# 매우 중요한 코드! 꼭 실행되어야 함

# %%
def add(a, b):
    try:
        return a + b # return하면 함수는 종료
    finally:
        print("실행")

# %%
add(10,20)
# Out:
# 실행
# 30

# %%
def login(user_id, user_pass):
    if user_id != 'user01':
        raise Exception("아이디가 일치하지 않습니다.")

    if user_pass != "1234":
        raise Exception("비밀번호가 일치하지 않습니다.")

    print("로그인 성공!")

# %%
login("user01","1234")
# Out:
# 로그인 성공!

# %%
login("user02","1111")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 login("user02","1111")
#
# Cell In[19], line 3, in login(user_id, user_pass)
#       1 def login(user_id, user_pass):
#       2     if user_id != 'user01':
# ----> 3         raise Exception("아이디가 일치하지 않습니다.")
#       5     if user_pass != "1234":
#       6         raise Exception("비밀번호가 일치하지 않습니다.")
#
# Exception: 아이디가 일치하지 않습니다.

# %%
class UserIdException(Exception): # Exception 클래스를 상속받으면 예외 클래스 됨
    pass

class UserPassException(Exception):
    pass

# %%
def login(userId, userPass):
    if userId != 'user01':
        raise UserIdException

    if userPass != 'userPass':
        raise UserPassException

    print("로그인 성공...")
